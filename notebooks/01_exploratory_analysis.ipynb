# %% [markdown]
# # 01 — Exploratory Analysis
# **Bachelor Thesis**: *Breaching Enterprise AI: A Quantitative Benchmarking of Emotional Soft Jailbreaking in Large Language Models*
#
# ---
# ### Notebook Goals
# 1. Load scored response data from `data/processed/`
# 2. Inspect distributions and check data quality
# 3. Run Kruskal-Wallis and Mann-Whitney U tests
# 4. Generate publication-ready figures

# %%
import sys
sys.path.insert(0, '../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from statistical_analysis import (
    descriptive_stats,
    kruskal_wallis_test,
    mann_whitney_posthoc,
    plot_score_distributions,
    plot_heatmap_median_scores,
)

sns.set_theme(style='whitegrid')
print('Environment ready.')

# %%
# Load processed scored data
# df = pd.read_csv('../data/processed/scored_results.csv')
# df.head()
